# %%
import pandas as pd
data = pd.read_csv('C:/Users/20212740/OneDrive - TU Eindhoven/Documents/Year 2/Q2/Visualization/cleaned_data.csv.xls')

# %%
data['testprice'] = data['price'].str[1:]
data['testprice'] = data['testprice'].str.replace(',','')

# %%
data['testprice'] = data['testprice'].astype(float)

# %%
data['testprice'].min()
# Out:
# 50.0

# %%
data['newservicefee'] = data['service fee'].str[1:]
data['newservicefee'] = data['newservicefee'].str.replace(',','')
data['newservicefee'] = data['newservicefee'].astype(float)

# %%
data['newservicefee'].max()
# Out:
# 240.0

# %%
data.head(50)
# Out:
#     Unnamed: 0       id                                               NAME  \
# 0            0  1001254                 Clean & quiet apt home by the park
# 1            1  1002102                              Skylit Midtown Castle
# 2            2  1002403                THE VILLAGE OF HARLEM....NEW YORK !
# 3            3  1002755                                                NaN
# 4            4  1003689   Entire Apt: Spacious Studio/Loft by central park
# 5            5  1004098          Large Cozy 1 BR Apartment In Midtown East
# 6            6  1004650                                    BlissArtsSpace!
# 7            7  1005202                                    BlissArtsSpace!
# 8            8  1005754                    Large Furnished Room Near B'way
# 9            9  1006307                 Cozy Clean Guest Room - Family Apt
# 10          10  1006859                 Cute & Cozy Lower East Side 1 bdrm
# ...

# %%
data['room type']
# Out:
# 0            Private room
# 1         Entire home/apt
# 2            Private room
# 3         Entire home/apt
# 4         Entire home/apt
#                ...
# 102581       Private room
# 102582       Private room
# 102583       Private room
# 102584    Entire home/apt
# 102585    Entire home/apt
# Name: room type, Length: 102586, dtype: object
